# %%
import pandas as pd

# %%
data = pd.read_csv("data/train.csv")

# %%
data = data.drop(2479)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = data["section"]
y = data["attendance"]

# %%
plt.scatter(x, y)

# %%
data_g_osaka = data[data["home_team"]=="G大阪"]

# %%
x = data_g_osaka["section"]
y = data_g_osaka["attendance"]
plt.scatter(x, y)

# %%
data_venue_banpaku = data[data["venue"] == "山梨県小瀬スポーツ公園陸上競技場"]

# %%
x = data_venue_banpaku["section"]
y = data_venue_banpaku["attendance"]
plt.scatter(x, y)

# %%
data_venue_banpaku_kiyomizu = data_venue_banpaku[data_venue_banpaku["away_team"] == "清水"]

# %%
x = data_venue_banpaku_kiyomizu["id"]
y = data_venue_banpaku_kiyomizu["attendance"]
plt.plot(x, y)

# %%
data_venue_banpaku_kiyomizu
# Out:
#         id  match_date kick_off_time section round home_team away_team  \
# 1     9191  2006-03-05         13:00     第1節   第2日        甲府        清水
# 411  10090  2007-05-19         19:04    第12節   第1日        甲府        清水
#
#                 venue weather  temperature  humidity  \
# 1    山梨県小瀬スポーツ公園陸上競技場       晴         12.9        28
# 411  山梨県小瀬スポーツ公園陸上競技場       曇         19.9        30
#
#                             broadcasters  attendance
# 1              山梨放送/テレビ静岡(録)/J SPORTS(録)       14277
# 411  スカパー!(パーフェクト チョイス)/e2(スカチャン!)(録)/BS       12422

# %%
data_urawa = data[data["home_team"] == "浦和"]

# %%
data_urawa
# Out:
#          id  match_date kick_off_time section round home_team away_team  \
# 9      9199  2006-03-11         14:04     第2節   第1日        浦和        磐田
# 29     9219  2006-03-21         15:04     第4節   第1日        浦和       C大阪
# 53     9243  2006-04-02         16:04     第6節   第2日        浦和       名古屋
# 64     9254  2006-04-15         15:05     第8節   第1日        浦和        京都
# 82     9272  2006-04-29         15:04    第10節   第1日        浦和        大宮
# 106    9296  2006-05-07         15:04    第12節   第2日        浦和        鹿島
# 126    9316  2006-07-26         19:04    第15節   第1日        浦和        大分
# 145    9335  2006-08-12         19:04    第17節   第1日        浦和      FC東京
# 162    9352  2006-08-23         19:04    第19節   第1日        浦和        新潟
# 201    9391  2006-09-16         19:04    第23節   第1日        浦和        広島
# 207    9397  2006-09-23         15:04    第24節   第1日        浦和        清水
# 226    9416  2006-10-07         15:04    第26節   第2日        浦和        千葉
# ...

# %%
x = data_urawa["away_team"]
y = data_urawa["attendance"]
plt.bar(x, y)
# Out:
# <BarContainer object of 186 artists>

# %%
data_urawa = data[data["away_team"] == "浦和"]
x = data_urawa["home_team"]
y = data_urawa["attendance"]
plt.bar(x, y)
# Out:
# <BarContainer object of 187 artists>

# %%
    # 時間をリスト化
    kick_off_time_list = pd.unique(data["kick_off_time"]).tolist()
    kick_off_time_list.sort()
    result = [kick_off_time_list[0:28],kick_off_time_list[28:76],kick_off_time_list[76:]]
    data.loc[data["kick_off_time"].isin(result[0]), "kick_off_time"] = "noon"
    data.loc[data["kick_off_time"].isin(result[1]), "kick_off_time"] = "evening"
    data.loc[data["kick_off_time"].isin(result[2]), "kick_off_time"] = "night"

# %%
x = data["kick_off_time"]
y = data["attendance"]
plt.scatter(x, y)

# %%
data = pd.read_csv("data/train.csv")
data = data.drop(2479)

# %%
x = data["kick_off_time"]
y = data["attendance"]
plt.scatter(x, y)

# %%
data.drop(data.index[13238:13543])
# Out:
#          id  match_date kick_off_time section round home_team away_team  \
# 0      9190  2006-03-04         16:04     第1節   第1日       G大阪        浦和
# 1      9191  2006-03-05         13:00     第1節   第2日        甲府        清水
# 2      9192  2006-03-05         13:35     第1節   第2日      FC東京        大分
# 3      9193  2006-03-05         14:04     第1節   第2日        磐田        福岡
# 4      9194  2006-03-05         14:04     第1節   第2日       名古屋       C大阪
# 5      9195  2006-03-05         15:03     第1節   第2日        大宮        千葉
# 6      9196  2006-03-05         15:00     第1節   第2日       川崎F        新潟
# 7      9197  2006-03-05         15:06     第1節   第2日        広島        鹿島
# 8      9198  2006-03-05         15:35     第1節   第2日      横浜FM        京都
# 9      9199  2006-03-11         14:04     第2節   第1日        浦和        磐田
# 10     9200  2006-03-11         15:02     第2節   第1日        千葉        甲府
# 11     9201  2006-03-11         15:04     第2節   第1日        新潟      FC東京
# ...
